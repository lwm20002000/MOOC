# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import edhec_risk_kit as erk
import numpy as np
import pandas as pd

ind = erk.get_ind_returns()
er = erk.annualize_rets(ind["2013":"2017"],12)
cov = ind["2013":"2017"].cov()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
erk.var_gaussian(ind["2000":],level=1)
# Out:
# Food     0.075367
# Beer     0.085803
# Smoke    0.136327
# Games    0.160742
# Books    0.138029
# Hshld    0.084121
# Clths    0.130560
# Hlth     0.085542
# Chems    0.129437
# Txtls    0.197790
# Cnstr    0.141382
# Steel    0.205368
# FabPr    0.152518
# ElcEq    0.144530
# Autos    0.186033
# Carry    0.129542
# Mines    0.178424
# Coal     0.301994
# Oil      0.129686
# Util     0.087101
# Telcm    0.119276
# Servs    0.137612
# BusEq    0.176027
# Paper    0.109716
# Trans    0.113027
# Whlsl    0.103012
# Rtail    0.103402
# Meals    0.094421
# Fin      0.123204
# Other    0.121501
# dtype: float64

# %%
ind.columns
# Out:
# Index(['Food', 'Beer', 'Smoke', 'Games', 'Books', 'Hshld', 'Clths', 'Hlth',
#        'Chems', 'Txtls', 'Cnstr', 'Steel', 'FabPr', 'ElcEq', 'Autos', 'Carry',
#        'Mines', 'Coal', 'Oil', 'Util', 'Telcm', 'Servs', 'BusEq', 'Paper',
#        'Trans', 'Whlsl', 'Rtail', 'Meals', 'Fin', 'Other'],
#       dtype='object')

# %%
hfi = erk.get_hfi_returns()

# %%
erk.var_historic(hfi["2000":],level=1)
# Out:
# Convertible Arbitrage     0.031674
# CTA Global                0.050938
# Distressed Securities     0.042642
# Emerging Markets          0.065496
# Equity Market Neutral     0.019800
# Event Driven              0.038540
# Fixed Income Arbitrage    0.030748
# Global Macro              0.022632
# Long/Short Equity         0.045060
# Merger Arbitrage          0.022654
# Relative Value            0.021788
# Short Selling             0.107684
# Funds Of Funds            0.027200
# dtype: float64

# %%
ind.head()
# Out:
#            Food    Beer   Smoke   Games   Books   Hshld   Clths    Hlth  \
# 1926-07  0.0056 -0.0519  0.0129  0.0293  0.1097 -0.0048  0.0808  0.0177
# 1926-08  0.0259  0.2703  0.0650  0.0055  0.1001 -0.0358 -0.0251  0.0425
# 1926-09  0.0116  0.0402  0.0126  0.0658 -0.0099  0.0073 -0.0051  0.0069
# 1926-10 -0.0306 -0.0331  0.0106 -0.0476  0.0947 -0.0468  0.0012 -0.0057
# 1926-11  0.0635  0.0729  0.0455  0.0166 -0.0580 -0.0054  0.0187  0.0542
#
#           Chems   Txtls  ...   Telcm   Servs   BusEq   Paper   Trans   Whlsl  \
# 1926-07  0.0814  0.0039  ...  0.0083  0.0922  0.0206  0.0770  0.0193 -0.2379
# 1926-08  0.0550  0.0814  ...  0.0217  0.0202  0.0439 -0.0238  0.0488  0.0539
# 1926-09  0.0533  0.0231  ...  0.0241  0.0225  0.0019 -0.0554  0.0005 -0.0787
# 1926-10 -0.0476  0.0100  ... -0.0011 -0.0200 -0.0109 -0.0508 -0.0264 -0.1538
# 1926-11  0.0520  0.0311  ...  0.0163  0.0377  0.0364  0.0384  0.0160  0.0467
#
#           Rtail   Meals     Fin   Other
# ...

# %%
ind.tail()
# Out:
#            Food    Beer   Smoke   Games   Books   Hshld   Clths    Hlth  \
# 2018-08 -0.0038 -0.0186 -0.0543  0.0289 -0.0447  0.0254  0.0526  0.0446
# 2018-09 -0.0032  0.0019  0.0537 -0.0009 -0.0221  0.0107  0.0130  0.0199
# 2018-10  0.0102 -0.0157  0.0790 -0.1596 -0.0666 -0.0051 -0.1014 -0.0884
# 2018-11  0.0272  0.0579 -0.0843 -0.0065  0.0325  0.0644 -0.0099  0.0632
# 2018-12 -0.0973 -0.0969 -0.1580 -0.0824 -0.1535 -0.0557 -0.0728 -0.0840
#
#           Chems   Txtls  ...   Telcm   Servs   BusEq   Paper   Trans   Whlsl  \
# 2018-08  0.0001  0.0380  ...  0.0295  0.0524  0.0993 -0.0034  0.0291  0.0366
# 2018-09 -0.0287 -0.0638  ...  0.0174 -0.0037 -0.0033 -0.0030  0.0105 -0.0148
# 2018-10 -0.1250 -0.2579  ... -0.0050 -0.0920 -0.0806 -0.0982 -0.0975 -0.0788
# 2018-11  0.0496  0.0292  ...  0.0254  0.0129 -0.0505  0.0822  0.0617  0.0318
# 2018-12 -0.0776 -0.1009  ... -0.0884 -0.0765 -0.0923 -0.0863 -0.1519 -0.1121
#
#           Rtail   Meals     Fin   Other
# ...

# %%
l = ["Books","Steel","Oil", "Mines"]
rf = 0.1
cov[l]
# Out:
#           Books     Steel       Oil     Mines
# Food   0.000713  0.000306  0.000429  0.000241
# Beer   0.000486  0.000327  0.000268  0.000089
# Smoke  0.000341  0.000267  0.000334  0.000342
# Games  0.001375  0.001246  0.001030  0.001147
# Books  0.002720  0.001940  0.001637  0.001539
# Hshld  0.000784  0.000614  0.000475  0.000249
# Clths  0.000896  0.000421  0.000167 -0.000095
# Hlth   0.001302  0.001086  0.000585  0.000337
# Chems  0.001636  0.001956  0.001555  0.001775
# Txtls  0.001854  0.001332  0.000736  0.000722
# Cnstr  0.001790  0.001894  0.001380  0.001289
# Steel  0.001940  0.004391  0.002122  0.003391
# FabPr  0.001668  0.002281  0.001767  0.001974
# ElcEq  0.001676  0.002137  0.001469  0.001520
# Autos  0.001743  0.001897  0.001253  0.001403
# Carry  0.001251  0.001558  0.000940  0.001083
# Mines  0.001539  0.003391  0.002179  0.005232
# Coal   0.002093  0.005574  0.003262  0.006282
# Oil    0.001637  0.002122  0.002697  0.002179
# ...

# %%
erk.plot_ef(20,er[l],cov.loc[l,l],show_cml=True,riskfree_rate=rf, show_ew=True)
# Out:
# [0.25 0.25 0.25 0.25]
# <AxesSubplot:xlabel='Volatility'>

# %%
w_msr = erk.msr(rf,er[l],cov.loc[l,l])

# %%
cov.loc[l,l]
# Out:
#           Books     Steel       Oil     Mines
# Books  0.002720  0.001940  0.001637  0.001539
# Steel  0.001940  0.004391  0.002122  0.003391
# Oil    0.001637  0.002122  0.002697  0.002179
# Mines  0.001539  0.003391  0.002179  0.005232

# %%
w_gmv = erk.gmv(cov.loc[l,l])

# %%
ind["2018"][l].cov()
# Out:
#           Books     Steel       Oil     Mines
# Books  0.002799  0.002098  0.002558  0.001629
# Steel  0.002098  0.004027  0.003473  0.001843
# Oil    0.002558  0.003473  0.005296  0.001961
# Mines  0.001629  0.001843  0.001961  0.002059

# %%
erk.portfolio_vol(w_gmv, ind["2018"][l].cov())
# Out:
# 0.054772453638838446

# %%
erk.var_gaussian(hfi["2000":],level=1, modified=True)
# Out:
# Convertible Arbitrage     0.103666
# CTA Global                0.046643
# Distressed Securities     0.049669
# Emerging Markets          0.086796
# Equity Market Neutral     0.041432
# Event Driven              0.045732
# Fixed Income Arbitrage    0.066479
# Global Macro              0.022786
# Long/Short Equity         0.051381
# Merger Arbitrage          0.021282
# Relative Value            0.048985
# Short Selling             0.098323
# Funds Of Funds            0.048793
# dtype: float64

# %%
er = erk.annualize_rets(ind["2013":"2017"],12)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# PeriodIndex: 60 entries, 2013-01 to 2017-12
# Freq: M
# Data columns (total 30 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Food    60 non-null     float64
#  1   Beer    60 non-null     float64
#  2   Smoke   60 non-null     float64
#  3   Games   60 non-null     float64
#  4   Books   60 non-null     float64
#  5   Hshld   60 non-null     float64
#  6   Clths   60 non-null     float64
#  7   Hlth    60 non-null     float64
#  8   Chems   60 non-null     float64
#  9   Txtls   60 non-null     float64
#  10  Cnstr   60 non-null     float64
#  11  Steel   60 non-null     float64
#  12  FabPr   60 non-null     float64
#  13  ElcEq   60 non-null     float64
#  14  Autos   60 non-null     float64
#  15  Carry   60 non-null     float64
#  16  Mines   60 non-null     float64
#  17  Coal    60 non-null     float64
#  18  Oil     60 non-null     float64
#  19  Util    60 non-null     float64
# ...

# %%
cov
# Out:
#            Food      Beer     Smoke     Games     Books     Hshld     Clths  \
# Food   0.000916  0.000709  0.000838  0.000586  0.000713  0.000680  0.000473
# Beer   0.000709  0.000899  0.000857  0.000369  0.000486  0.000657  0.000369
# Smoke  0.000838  0.000857  0.001815  0.000549  0.000341  0.000737  0.000384
# Games  0.000586  0.000369  0.000549  0.002458  0.001375  0.000533  0.000436
# Books  0.000713  0.000486  0.000341  0.001375  0.002720  0.000784  0.000896
# Hshld  0.000680  0.000657  0.000737  0.000533  0.000784  0.000928  0.000531
# Clths  0.000473  0.000369  0.000384  0.000436  0.000896  0.000531  0.001437
# Hlth   0.000564  0.000526  0.000386  0.001045  0.001302  0.000675  0.000538
# Chems  0.000564  0.000348  0.000439  0.001528  0.001636  0.000595  0.000532
# Txtls  0.000736  0.000574  0.000229  0.001115  0.001854  0.000728  0.000839
# Cnstr  0.000598  0.000294  0.000206  0.001495  0.001790  0.000625  0.000739
# ...

# %%
rf
# Out:
# 0.1

# %%
erk.msr(rf,er[l],cov.loc[l,l])
# Out:
# array([4.51375048e-15, 1.00000000e+00, 1.40512602e-16, 0.00000000e+00])

# %%
erk.gmv(cov.loc[l,l])
# Out:
# array([4.77024870e-01, 4.33680869e-19, 4.34112024e-01, 8.88631053e-02])

# %%
4.34112024+4.77024870+0.888631053
# Out:
# 9.999999993

# %%
w_gmv
# Out:
# array([4.77024870e-01, 4.33680869e-19, 4.34112024e-01, 8.88631053e-02])

# %%
w_msr
# Out:
# array([4.51375048e-15, 1.00000000e+00, 1.40512602e-16, 0.00000000e+00])

# %%
ind["2018"][l].cov()
# Out:
#           Books     Steel       Oil     Mines
# Books  0.002799  0.002098  0.002558  0.001629
# Steel  0.002098  0.004027  0.003473  0.001843
# Oil    0.002558  0.003473  0.005296  0.001961
# Mines  0.001629  0.001843  0.001961  0.002059

# %%
erk.portfolio_vol(w_msr, ind["2018"][l].cov())
# Out:
# 0.06346230747220709

# %%
w_msr[2] = 0
w_msr
# Out:
# array([0., 1., 0., 0.])

# %%
erk.portfolio_vol(w_msr, ind["2018"][l].cov())
# Out:
# 0.06346230747220692

# %%
erk.portfolio_vol(w_gmv, ind["2018"][l].cov())
# Out:
# 0.054772453638838446

# %%
ind["2018"][l]
# Out:
#           Books   Steel     Oil   Mines
# 2018-01  0.0449  0.0361  0.0286  0.0357
# 2018-02 -0.0325 -0.0199 -0.1102 -0.0335
# 2018-03  0.0031 -0.0586  0.0308 -0.0015
# 2018-04 -0.0062  0.0366  0.1030 -0.0339
# 2018-05 -0.0061  0.0562  0.0343  0.0308
# 2018-06  0.0218 -0.0514  0.0052 -0.0178
# 2018-07 -0.0417  0.0424  0.0104 -0.0224
# 2018-08 -0.0447 -0.0323 -0.0295 -0.1075
# 2018-09 -0.0221 -0.0067  0.0356 -0.0173
# 2018-10 -0.0666 -0.1161 -0.1206 -0.1032
# 2018-11  0.0325 -0.0300 -0.0233 -0.0095
# 2018-12 -0.1535 -0.1478 -0.1325 -0.0706
