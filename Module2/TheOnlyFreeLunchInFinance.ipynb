# %% [markdown]
# # Asset Combinations
#
# - With Half in A and half in B
# - The return is the weighted average of all components of portfolio
#
# - However, risk is different
# - We need the correlation between A and B, Behaviour of both assts together.
#     - If there is no correlation, it is less volatile as a portfolio, therefore less resultant risk.
#     - More correlation will lead to a higher weighted risk.
#
# Question: If A and B are perfectly correlated, then the volatility of a portfolio that is 50% in A and 50% in B is the average of the volatilities of A and B
#
# Answer: True
#
# The returns of perfectly correlated portfolios are in sync with each other and the portfolio volatility is the average of the volatilities of A and B
#
# ![Screen Shot 2020-12-23 at 10.24.04.png](attachment:9f9cab2a-9cf5-4fd1-a2e0-470ec32e15d5.png)
#
# Question: The volatility of a portfolio of two assets that have non-zero weights and a correlation coefficient of 0.9 is always strictly lower than the weighted average volatility of the two assets.
#
# Answer: True
#
# As long as the two weights are non-zero and the correlation between the two assets are less than 1, the volatility of the portfolio will always be less than the weighted average volatilities of the two assets.
#
# - Magic of diversification
#
# ![Screen Shot 2020-12-23 at 10.27.51.png](attachment:f261eca5-9703-4557-a760-5ff9f7e17d96.png)
#
# Mixing Assets A and B as a portfolio, we can acheive a reulting volatility lower than both A and B.
#
#
# Question: An analyst tells you that the minimum volatility portfolio you can construct from two risky assets X and Y is to put 100% of your capital in X. What is the analyst telling you?
#
# Answer: Either X and Y are perfectly correlated
#
# If X and Y are perfectly correlated, the minimum value portfolio is obtained by putting 100% of your capital in the portfolio with the lower of the two volatilities
#
# ![Screen Shot 2020-12-23 at 10.30.39.png](attachment:943ae845-ef53-4459-8b07-0fca1ce0290d.png)
#
# The curve depends on the correlation coefficient. The less correlation, the steeper curve, resulting in a reultant lower volatility.
# Portfolio construction is about exploiting the correlation within choices of your portfolio in order to acheive the only free lunch in all of finance of lower volatility.
#
# Question: The lowest possible volatility you can construct from a portfolio of two assets A and B
#
# Answer: INCREASES as the correlation between A and B increases
# CORRECT as correlations increase, the volatility of the minimum possible volatility portfolio increases
#
# There will always be a better portfolio to hold.
